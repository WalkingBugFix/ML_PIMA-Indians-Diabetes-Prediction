# %%
import warnings

warnings.filterwarnings("ignore")

# Libraries to help with reading and manipulating data
import pandas as pd
import numpy as np

# libaries to help with data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Library to split data
from sklearn.model_selection import train_test_split


# To build linear model for statistical analysis and prediction
import statsmodels.stats.api as sms
from statsmodels.stats.outliers_influence import variance_inflation_factor
import statsmodels.api as sm
from statsmodels.tools.tools import add_constant

# To get diferent metric scores
from sklearn import metrics
from sklearn.metrics import accuracy_score, roc_curve, confusion_matrix, roc_auc_score

# %%
data = pd.read_csv('pima-indians-diabetes.csv')

# %%
data.head()
# Out:
#    Preg  Plas  Pres  skin  test  mass   pedi  age  class
# 0     6   148    72    35     0  33.6  0.627   50      1
# 1     1    85    66    29     0  26.6  0.351   31      0
# 2     8   183    64     0     0  23.3  0.672   32      1
# 3     1    89    66    23    94  28.1  0.167   21      0
# 4     0   137    40    35   168  43.1  2.288   33      1

# %%
data.rename(columns={'Preg':'Pregnancy',
                      'Plas':'Glucose',
                      'Pres':'BloodPressure',
                      'skin':'SkinThickness',
                      'test':'Insulin',
                      'mass':'BMI',
                      'pedi':'Pedigree',
                      'age':'Age',
                      'class':'Class'}, inplace=True)

# %%
data.head()
# Out:
#    Pregnancy  Glucose  BloodPressure  SkinThickness  Insulin   BMI  Pedigree  \
# 0          6      148             72             35        0  33.6     0.627
# 1          1       85             66             29        0  26.6     0.351
# 2          8      183             64              0        0  23.3     0.672
# 3          1       89             66             23       94  28.1     0.167
# 4          0      137             40             35      168  43.1     2.288
#
#    Age  Class
# 0   50      1
# 1   31      0
# 2   32      1
# 3   21      0
# 4   33      1

# %%
data.isna().sum()
# Out:
# Pregnancy        0
# Glucose          0
# BloodPressure    0
# SkinThickness    0
# Insulin          0
# BMI              0
# Pedigree         0
# Age              0
# Class            0
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Pregnancy        0
# Glucose          0
# BloodPressure    0
# SkinThickness    0
# Insulin          0
# BMI              0
# Pedigree         0
# Age              0
# Class            0
# dtype: int64

# %%
data.isin([0]).sum()
# Out:
# Pregnancy        111
# Glucose            5
# BloodPressure     35
# SkinThickness    227
# Insulin          374
# BMI               11
# Pedigree           0
# Age                0
# Class            500
# dtype: int64

# %%
data.hist(figsize=(15,7))
plt.show();

# %%
cols = ['Glucose','BloodPressure','SkinThickness','Insulin','BMI']

# %%
data[cols] = data[cols].replace(0, np.nan)

# %%
data[cols] = data[cols].fillna(data[cols].mean())

# %%
data.isna().sum()
# Out:
# Pregnancy        0
# Glucose          0
# BloodPressure    0
# SkinThickness    0
# Insulin          0
# BMI              0
# Pedigree         0
# Age              0
# Class            0
# dtype: int64

# %%
data.isin([0]).sum()
# Out:
# Pregnancy        111
# Glucose            0
# BloodPressure      0
# SkinThickness      0
# Insulin            0
# BMI                0
# Pedigree           0
# Age                0
# Class            500
# dtype: int64

# %% [markdown]
# ### Bivariate analysis

# %%
plt.figure(figsize=(15,7))
sns.heatmap(data.corr(), annot=True, vmin=-1, vmax=1)
plt.show();

# %%
sns.pairplot(data, hue='Class')
plt.show();

# %%
round(data['Class'].value_counts(1)*100,2)
# Out:
# Class
# 0    65.1
# 1    34.9
# Name: proportion, dtype: float64

# %%
x = data.drop(['Class'], axis=1)
y = data['Class']
x = add_constant(x)
x = pd.get_dummies(x, drop_first=True)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, stratify = y, random_state = 1)

# %%
logit = sm.Logit(y_train, x_train.astype(float))
lg = logit.fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.449508
#          Iterations 6

# %%
print(lg.summary())
# Out:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                  Class   No. Observations:                  537
# Model:                          Logit   Df Residuals:                      528
# Method:                           MLE   Df Model:                            8
# Date:                Wed, 09 Apr 2025   Pseudo R-squ.:                  0.3045
# Time:                        23:24:40   Log-Likelihood:                -241.39
# converged:                       True   LL-Null:                       -347.09
# Covariance Type:            nonrobust   LLR p-value:                 2.518e-41
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -9.7226      1.021     -9.522      0.000     -11.724      -7.721
# Pregnancy         0.1445      0.039      3.706      0.000       0.068       0.221
# Glucose           0.0363      0.005      7.819      0.000       0.027       0.045
# BloodPressure    -0.0038      0.010     -0.359      0.720      -0.024       0.017
# SkinThickness     0.0008      0.016      0.048      0.962      -0.031       0.032
# Insulin           0.0010      0.002      0.644      0.519      -0.002       0.004
# BMI               0.0936      0.022      4.186      0.000       0.050       0.137
# Pedigree          1.0345      0.351      2.950      0.003       0.347       1.722
# Age               0.0122      0.011      1.070      0.284      -0.010       0.035
# =================================================================================

# %%
pred_train = np.round(lg.predict(x_train)>0.5)

# %%
confusion_matrix(y_train, pred_train)
# Out:
# array([[308,  42],
#        [ 73, 114]], dtype=int64)

# %%
accuracy_score(y_train, pred_train)
# Out:
# 0.7858472998137802

# %%
vif_series = pd.Series([variance_inflation_factor(x_train.values, i) for i in range(x_train.shape[1])],
                       index=x_train.columns,
                       dtype=float)
vif_series
# Out:
# const            55.156267
# Pregnancy         1.418041
# Glucose           1.358583
# BloodPressure     1.226593
# SkinThickness     1.446856
# Insulin           1.227806
# BMI               1.546783
# Pedigree          1.054447
# Age               1.637294
# dtype: float64

# %%
x_train1 = x_train.drop(['SkinThickness'], axis=1)

# %%
lg1 = sm.Logit(y_train, x_train1.astype(float)).fit()
pred_train1 = np.round(lg1.predict(x_train1))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.449511
#          Iterations 6

# %%
print(lg1.summary())
# Out:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                  Class   No. Observations:                  537
# Model:                          Logit   Df Residuals:                      529
# Method:                           MLE   Df Model:                            7
# Date:                Wed, 09 Apr 2025   Pseudo R-squ.:                  0.3045
# Time:                        23:27:40   Log-Likelihood:                -241.39
# converged:                       True   LL-Null:                       -347.09
# Covariance Type:            nonrobust   LLR p-value:                 4.406e-42
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -9.7189      1.018     -9.548      0.000     -11.714      -7.724
# Pregnancy         0.1446      0.039      3.707      0.000       0.068       0.221
# Glucose           0.0363      0.005      7.820      0.000       0.027       0.045
# BloodPressure    -0.0038      0.010     -0.359      0.720      -0.024       0.017
# Insulin           0.0010      0.002      0.646      0.518      -0.002       0.004
# BMI               0.0942      0.020      4.811      0.000       0.056       0.133
# Pedigree          1.0348      0.351      2.952      0.003       0.348       1.722
# Age               0.0123      0.011      1.080      0.280      -0.010       0.035
# =================================================================================

# %%
x_train2 = x_train1.drop(['BloodPressure'], axis=1)

# %%
lg2 = sm.Logit(y_train, x_train2.astype(float)).fit()
pred_train2 = np.round(lg2.predict(x_train2))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.449630
#          Iterations 6

# %%
print(lg2.summary())
# Out:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                  Class   No. Observations:                  537
# Model:                          Logit   Df Residuals:                      530
# Method:                           MLE   Df Model:                            6
# Date:                Wed, 09 Apr 2025   Pseudo R-squ.:                  0.3043
# Time:                        23:28:52   Log-Likelihood:                -241.45
# converged:                       True   LL-Null:                       -347.09
# Covariance Type:            nonrobust   LLR p-value:                 7.548e-43
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -9.8778      0.919    -10.744      0.000     -11.680      -8.076
# Pregnancy      0.1442      0.039      3.702      0.000       0.068       0.220
# Glucose        0.0361      0.005      7.837      0.000       0.027       0.045
# Insulin        0.0010      0.002      0.671      0.502      -0.002       0.004
# BMI            0.0922      0.019      4.903      0.000       0.055       0.129
# Pedigree       1.0394      0.350      2.973      0.003       0.354       1.725
# Age            0.0112      0.011      1.024      0.306      -0.010       0.033
# ==============================================================================

# %%
x_train3 = x_train2.drop(['Insulin'], axis=1)

# %%
lg3 = sm.Logit(y_train, x_train3.astype(float)).fit()
pred_train3 = np.round(lg3.predict(x_train3))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.450056
#          Iterations 6

# %%
print(lg3.summary())
# Out:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                  Class   No. Observations:                  537
# Model:                          Logit   Df Residuals:                      531
# Method:                           MLE   Df Model:                            5
# Date:                Wed, 09 Apr 2025   Pseudo R-squ.:                  0.3037
# Time:                        23:29:55   Log-Likelihood:                -241.68
# converged:                       True   LL-Null:                       -347.09
# Covariance Type:            nonrobust   LLR p-value:                 1.378e-43
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -9.8936      0.921    -10.746      0.000     -11.698      -8.089
# Pregnancy      0.1440      0.039      3.686      0.000       0.067       0.221
# Glucose        0.0372      0.004      8.584      0.000       0.029       0.046
# BMI            0.0937      0.019      5.005      0.000       0.057       0.130
# Pedigree       1.0388      0.349      2.972      0.003       0.354       1.724
# Age            0.0112      0.011      1.016      0.310      -0.010       0.033
# ==============================================================================

# %%
x_train4 = x_train3.drop('Age', axis=1)

# %%
lg4 = sm.Logit(y_train, x_train4.astype(float)).fit()
pred_train4 = np.round(lg4.predict(x_train4))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.451011
#          Iterations 6

# %%
print(lg4.summary())
# Out:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                  Class   No. Observations:                  537
# Model:                          Logit   Df Residuals:                      532
# Method:                           MLE   Df Model:                            4
# Date:                Wed, 09 Apr 2025   Pseudo R-squ.:                  0.3022
# Time:                        23:34:06   Log-Likelihood:                -242.19
# converged:                       True   LL-Null:                       -347.09
# Covariance Type:            nonrobust   LLR p-value:                 2.951e-44
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -9.6760      0.890    -10.873      0.000     -11.420      -7.932
# Pregnancy      0.1645      0.034      4.881      0.000       0.098       0.231
# Glucose        0.0381      0.004      8.943      0.000       0.030       0.046
# BMI            0.0927      0.019      4.955      0.000       0.056       0.129
# Pedigree       1.0442      0.349      2.996      0.003       0.361       1.727
# ==============================================================================

# %%
odds = np.exp(lg4.params)
pd.DataFrame(odds, x_train4.columns, columns=['odds']).T
# Out:
#          const  Pregnancy   Glucose       BMI  Pedigree
# odds  0.000063   1.178781  1.038845  1.097174  2.841249

# %%
perc_change_odds = (np.exp(lg4.params)-1)*100
pd.DataFrame(perc_change_odds, x_train4.columns, columns=['change_odds%']).T
# Out:
#                   const  Pregnancy   Glucose       BMI    Pedigree
# change_odds% -99.993723  17.878143  3.884519  9.717385  184.124936

# %% [markdown]
# ### Final Model Performance

# %%
confusion_matrix(y_train, pred_train4)
# Out:
# array([[310,  40],
#        [ 77, 110]], dtype=int64)

# %%
accuracy_score(y_train, pred_train4)
# Out:
# 0.7821229050279329

# %%
fpr, tpr, _ = roc_curve(y_train, lg4.predict(x_train4))
plt.plot(fpr, tpr)
plt.plot([0,1],[0,1], linestyle='--',color='grey')
plt.show();

# %%
auc_score = roc_auc_score(y_train, lg4.predict(x_train4))
auc_score
# Out:
# 0.8532620320855615

# %% [markdown]
# ### Final Prediction of Test Data

# %%
x_test = x_test.drop(['SkinThickness','BloodPressure','Insulin','Age'],axis=1)

# %%
pred_test = np.round(lg4.predict(x_test)>0.5)

# %%
accuracy_score(y_train, pred_train4)
# Out:
# 0.7821229050279329

# %%
accuracy_score(y_test, pred_test)
# Out:
# 0.7489177489177489
